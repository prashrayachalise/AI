# %% [markdown]
# #PIMA INDIANS DIABETES DATABASE

# %% [markdown]
# Introduction
#
# This dataset is form national institute of Diabetes and Digestive and Kidney Diseases. This dataset is to predict whether a patient has diabetes or not which is based on certain diagnostic measurements. which has several data such as Pregnancies ,Glucose ,BloodPressure ,SkinThickness ,Insulin ,BMI ,DiabetesPedigreeFunction ,Age and Outcome.

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/AI/week7Ai/diabetes.csv'
df = pd.read_csv(file_path)
print(df.head(10))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %%
print(df.tail)
# Out:
# <bound method NDFrame.tail of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.shape
# Out:
# (768, 9)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plotting a histogram for Glucose
plt.figure(figsize=(8,6))
sns.histplot(df['Glucose'], bins=20, color='skyblue')
plt.title('Distribution of Glucose')
plt.xlabel('Glucose')
plt.ylabel('Frequency')
plt.show()

# %%
# Boxplot for Age vs Outcome
plt.figure(figsize=(8,6))
sns.boxplot(x='Outcome', y='Age', data=df)
plt.title('Age vs Outcome')
plt.xlabel('Diabetic (1) / Non-diabetic (0)')
plt.ylabel('Age')
plt.show()

# %%
# Bar plot for average number of pregnancies by Outcome
plt.figure(figsize=(8,6))
sns.barplot(x='Outcome', y='Pregnancies', data=df, palette='Set2')
plt.title('Average Number of Pregnancies by Outcome')
plt.xlabel('Diabetic (1) / Non-diabetic (0)')
plt.ylabel('Average Pregnancies')
plt.show()
# Out:
# <ipython-input-9-47931096414a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Outcome', y='Pregnancies', data=df, palette='Set2')

# %%
import pandas as pd
import matplotlib.pyplot as plt

file_path = '/content/drive/MyDrive/AI/week7Ai/diabetes.csv'
data = pd.read_csv(file_path)

plt.figure(figsize=(8, 6))
data[['Age', 'Insulin']].boxplot()
plt.title("Box Plot for Age and Insulin")
plt.ylabel("Values")
plt.grid(False)
plt.show()

# %%
# Scatter plot for Glucose vs BMI colored by Outcome
plt.figure(figsize=(8,6))
sns.scatterplot(x='Glucose', y='BMI', hue='Outcome', data=df, palette='coolwarm')
plt.title('Glucose vs BMI by Outcome')
plt.xlabel('Glucose')
plt.ylabel('BMI')
plt.show()

# %%
# Pie chart for Outcome distribution
outcome_counts = df['Outcome'].value_counts()
plt.figure(figsize=(6,6))
outcome_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightskyblue'])
plt.title('Proportion of Diabetic vs Non-diabetic Patients')
plt.ylabel('')
plt.show()

# %%
x = df.drop(columns=['BloodPressure'])
y = df['BloodPressure']

# %%
x.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'SkinThickness', 'Insulin', 'BMI',
#        'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import ttest_ind
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared:", {r2}')
# Out:
# Mean Squared Error: 402.8523890426408
# R-squared:", 0.19403775986668126
